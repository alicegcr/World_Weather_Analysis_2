# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 755

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ba3d84fec7c631a7b0ad30e846419e09"
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ba3d84fec7c631a7b0ad30e846419e09

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(5)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Description": city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bengkulu
# Processing Record 2 of Set 1 | felidhoo
# City not found. Skipping...
# Processing Record 3 of Set 1 | nowy sacz
# Processing Record 4 of Set 1 | portland
# Processing Record 5 of Set 1 | tasiilaq
# Processing Record 6 of Set 1 | butaritari
# Processing Record 7 of Set 1 | cherskiy
# Processing Record 8 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | busselton
# Processing Record 11 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 12 of Set 1 | albany
# Processing Record 13 of Set 1 | hobart
# Processing Record 14 of Set 1 | avarua
# Processing Record 15 of Set 1 | chokurdakh
# Processing Record 16 of Set 1 | yunhe
# Processing Record 17 of Set 1 | goderich
# Processing Record 18 of Set 1 | constitucion
# Processing Record 19 of Set 1 | katha
# City not found. Skipping...
# Processing Record 20 of Set 1 | verkhnevilyuysk
# Processing Record 21 of Set 1 | boa vista
# Processing Record 22 of Set 1 | lakes entrance
# Processing Record 23 of Set 1 | baracoa
# Processing Record 24 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 25 of Set 1 | cape town
# Processing Record 26 of Set 1 | novoomskiy
# Processing Record 27 of Set 1 | lorengau
# Processing Record 28 of Set 1 | natal
# Processing Record 29 of Set 1 | los llanos de aridane
# Processing Record 30 of Set 1 | yarim
# Processing Record 31 of Set 1 | tuktoyaktuk
# Processing Record 32 of Set 1 | punta arenas
# Processing Record 33 of Set 1 | namibe
# Processing Record 34 of Set 1 | bukama
# Processing Record 35 of Set 1 | maarianhamina
# Processing Record 36 of Set 1 | hermanus
# Processing Record 37 of Set 1 | katsuura
# Processing Record 38 of Set 1 | torbay
# Processing Record 39 of Set 1 | olavarria
# Processing Record 40 of Set 1 | nikolskoye
# Processing Record 41 of Set 1 | bredasdorp
# Processing Record 42 of Set 1 | antalaha
# Processing Record 43 of Set 1 | kruisfontein
# Processing Record 44 of Set 1 | malwan
# City not found. Skipping...
# Processing Record 45 of Set 1 | mataura
# Processing Record 46 of Set 1 | alice springs
# Processing Record 47 of Set 1 | lompoc
# Processing Record 48 of Set 1 | pevek
# Processing Record 49 of Set 1 | saint-philippe
# Processing Record 50 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 1 of Set 2 | chuy
# Processing Record 2 of Set 2 | toora-khem
# Processing Record 3 of Set 2 | ushuaia
# Processing Record 4 of Set 2 | taldan
# Processing Record 5 of Set 2 | hilo
# Processing Record 6 of Set 2 | nouakchott
# Processing Record 7 of Set 2 | vaini
# Processing Record 8 of Set 2 | new norfolk
# Processing Record 9 of Set 2 | jamestown
# Processing Record 10 of Set 2 | bafra
# Processing Record 11 of Set 2 | bluff
# Processing Record 12 of Set 2 | vila
# Processing Record 13 of Set 2 | yulara
# Processing Record 14 of Set 2 | wuwei
# Processing Record 15 of Set 2 | hithadhoo
# Processing Record 16 of Set 2 | kavieng
# Processing Record 17 of Set 2 | martapura
# Processing Record 18 of Set 2 | mbanza-ngungu
# Processing Record 19 of Set 2 | georgetown
# Processing Record 20 of Set 2 | namatanai
# Processing Record 21 of Set 2 | nouadhibou
# Processing Record 22 of Set 2 | guerrero negro
# Processing Record 23 of Set 2 | talnakh
# Processing Record 24 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 25 of Set 2 | yelniki
# Processing Record 26 of Set 2 | east london
# Processing Record 27 of Set 2 | zhanaozen
# Processing Record 28 of Set 2 | hays
# Processing Record 29 of Set 2 | kapaa
# Processing Record 30 of Set 2 | ambilobe
# Processing Record 31 of Set 2 | tubruq
# City not found. Skipping...
# Processing Record 32 of Set 2 | brewster
# Processing Record 33 of Set 2 | yerbogachen
# Processing Record 34 of Set 2 | lagoa
# Processing Record 35 of Set 2 | bagdarin
# Processing Record 36 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 37 of Set 2 | pokaran
# Processing Record 38 of Set 2 | abu samrah
# Processing Record 39 of Set 2 | hofn
# Processing Record 40 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 41 of Set 2 | hami
# Processing Record 42 of Set 2 | qaanaaq
# Processing Record 43 of Set 2 | chifeng
# Processing Record 44 of Set 2 | xiaoweizhai
# Processing Record 45 of Set 2 | tinqueux
# Processing Record 46 of Set 2 | muli
# Processing Record 47 of Set 2 | kalanwali
# Processing Record 48 of Set 2 | bury saint edmunds
# City not found. Skipping...
# Processing Record 49 of Set 2 | landeck
# Processing Record 50 of Set 2 | thayetmyo
# Processing Record 1 of Set 3 | bandarbeyla
# Processing Record 2 of Set 3 | kidal
# Processing Record 3 of Set 3 | khatanga
# Processing Record 4 of Set 3 | beloha
# Processing Record 5 of Set 3 | labuhan
# Processing Record 6 of Set 3 | te anau
# Processing Record 7 of Set 3 | prince rupert
# Processing Record 8 of Set 3 | cidreira
# Processing Record 9 of Set 3 | middelkerke
# Processing Record 10 of Set 3 | socorro
# Processing Record 11 of Set 3 | awjilah
# Processing Record 12 of Set 3 | srednekolymsk
# Processing Record 13 of Set 3 | maniitsoq
# Processing Record 14 of Set 3 | yarada
# Processing Record 15 of Set 3 | marang
# Processing Record 16 of Set 3 | liverpool
# Processing Record 17 of Set 3 | sioux lookout
# Processing Record 18 of Set 3 | puerto ayora
# Processing Record 19 of Set 3 | berlevag
# Processing Record 20 of Set 3 | tabas
# Processing Record 21 of Set 3 | chatrapur
# Processing Record 22 of Set 3 | sitka
# Processing Record 23 of Set 3 | ola
# Processing Record 24 of Set 3 | lavrentiya
# Processing Record 25 of Set 3 | fort saint john
# City not found. Skipping...
# Processing Record 26 of Set 3 | ugoofaaru
# Processing Record 27 of Set 3 | victoria
# Processing Record 28 of Set 3 | husavik
# Processing Record 29 of Set 3 | ancud
# Processing Record 30 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 31 of Set 3 | troitsko-pechorsk
# Processing Record 32 of Set 3 | dombarovskiy
# Processing Record 33 of Set 3 | formoso do araguaia
# City not found. Skipping...
# Processing Record 34 of Set 3 | steinbach
# Processing Record 35 of Set 3 | barrow
# Processing Record 36 of Set 3 | koutsouras
# Processing Record 37 of Set 3 | severo-kurilsk
# Processing Record 38 of Set 3 | belmonte
# Processing Record 39 of Set 3 | ahipara
# Processing Record 40 of Set 3 | kutum
# Processing Record 41 of Set 3 | ivanivka
# Processing Record 42 of Set 3 | progreso
# Processing Record 43 of Set 3 | ciudad bolivar
# Processing Record 44 of Set 3 | ozinki
# Processing Record 45 of Set 3 | mar del plata
# Processing Record 46 of Set 3 | movileni
# Processing Record 47 of Set 3 | bethel
# Processing Record 48 of Set 3 | waipawa
# Processing Record 49 of Set 3 | lasa
# Processing Record 50 of Set 3 | alofi
# Processing Record 1 of Set 4 | jiuquan
# Processing Record 2 of Set 4 | haines junction
# Processing Record 3 of Set 4 | abadiania
# Processing Record 4 of Set 4 | durant
# Processing Record 5 of Set 4 | port hardy
# Processing Record 6 of Set 4 | jalu
# Processing Record 7 of Set 4 | nantucket
# Processing Record 8 of Set 4 | harper
# Processing Record 9 of Set 4 | manggar
# Processing Record 10 of Set 4 | konde
# Processing Record 11 of Set 4 | kaeo
# Processing Record 12 of Set 4 | tiksi
# Processing Record 13 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 14 of Set 4 | manzhouli
# Processing Record 15 of Set 4 | yellowknife
# Processing Record 16 of Set 4 | abu kamal
# Processing Record 17 of Set 4 | kavarna
# Processing Record 18 of Set 4 | ponta do sol
# Processing Record 19 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 20 of Set 4 | baykit
# Processing Record 21 of Set 4 | norman wells
# Processing Record 22 of Set 4 | burg
# Processing Record 23 of Set 4 | erenhot
# Processing Record 24 of Set 4 | souillac
# Processing Record 25 of Set 4 | gopichettipalaiyam
# City not found. Skipping...
# Processing Record 26 of Set 4 | altamira
# Processing Record 27 of Set 4 | guajara-mirim
# City not found. Skipping...
# Processing Record 28 of Set 4 | atuona
# Processing Record 29 of Set 4 | armidale
# Processing Record 30 of Set 4 | graaff-reinet
# Processing Record 31 of Set 4 | state college
# Processing Record 32 of Set 4 | bad wildungen
# Processing Record 33 of Set 4 | innisfail
# Processing Record 34 of Set 4 | rovaniemi
# Processing Record 35 of Set 4 | kavaratti
# Processing Record 36 of Set 4 | komsomolskiy
# Processing Record 37 of Set 4 | severodvinsk
# Processing Record 38 of Set 4 | nanortalik
# Processing Record 39 of Set 4 | rodrigues alves
# Processing Record 40 of Set 4 | port elizabeth
# Processing Record 41 of Set 4 | nago
# Processing Record 42 of Set 4 | norsup
# Processing Record 43 of Set 4 | grand gaube
# Processing Record 44 of Set 4 | bac lieu
# Processing Record 45 of Set 4 | cururupu
# Processing Record 46 of Set 4 | thompson
# Processing Record 47 of Set 4 | arlit
# Processing Record 48 of Set 4 | kamenka
# Processing Record 49 of Set 4 | hailun
# Processing Record 50 of Set 4 | plettenberg bay
# Processing Record 1 of Set 5 | kommunisticheskiy
# Processing Record 2 of Set 5 | half moon bay
# Processing Record 3 of Set 5 | semporna
# Processing Record 4 of Set 5 | kahului
# Processing Record 5 of Set 5 | ranong
# Processing Record 6 of Set 5 | kodiak
# Processing Record 7 of Set 5 | awbari
# Processing Record 8 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 9 of Set 5 | baruun-urt
# Processing Record 10 of Set 5 | alghero
# Processing Record 11 of Set 5 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 12 of Set 5 | mamallapuram
# Processing Record 13 of Set 5 | korla
# Processing Record 14 of Set 5 | juneau
# Processing Record 15 of Set 5 | castro
# Processing Record 16 of Set 5 | miri
# Processing Record 17 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 18 of Set 5 | longyearbyen
# Processing Record 19 of Set 5 | esperance
# Processing Record 20 of Set 5 | orotukan
# Processing Record 21 of Set 5 | moussoro
# Processing Record 22 of Set 5 | carnarvon
# Processing Record 23 of Set 5 | aljezur
# Processing Record 24 of Set 5 | santa rosa
# Processing Record 25 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 26 of Set 5 | airai
# Processing Record 27 of Set 5 | qui nhon
# Processing Record 28 of Set 5 | upernavik
# Processing Record 29 of Set 5 | port hedland
# Processing Record 30 of Set 5 | saldanha
# Processing Record 31 of Set 5 | eydhafushi
# Processing Record 32 of Set 5 | ponta delgada
# Processing Record 33 of Set 5 | yarmouth
# Processing Record 34 of Set 5 | araouane
# Processing Record 35 of Set 5 | dudinka
# Processing Record 36 of Set 5 | mount gambier
# Processing Record 37 of Set 5 | palana
# Processing Record 38 of Set 5 | eirunepe
# Processing Record 39 of Set 5 | la ronge
# Processing Record 40 of Set 5 | nimbahera
# Processing Record 41 of Set 5 | brzi brod
# City not found. Skipping...
# Processing Record 42 of Set 5 | guider
# Processing Record 43 of Set 5 | san cristobal
# Processing Record 44 of Set 5 | coahuayana
# Processing Record 45 of Set 5 | baft
# Processing Record 46 of Set 5 | wittlich
# Processing Record 47 of Set 5 | lebu
# Processing Record 48 of Set 5 | urdzhar
# City not found. Skipping...
# Processing Record 49 of Set 5 | tubuala
# Processing Record 50 of Set 5 | furstenfeld
# Processing Record 1 of Set 6 | antofagasta
# Processing Record 2 of Set 6 | piney green
# Processing Record 3 of Set 6 | bilibino
# Processing Record 4 of Set 6 | sao filipe
# Processing Record 5 of Set 6 | palmer
# Processing Record 6 of Set 6 | port alfred
# Processing Record 7 of Set 6 | geraldton
# Processing Record 8 of Set 6 | maceio
# Processing Record 9 of Set 6 | isla vista
# Processing Record 10 of Set 6 | lerwick
# Processing Record 11 of Set 6 | cabo san lucas
# Processing Record 12 of Set 6 | kalmunai
# Processing Record 13 of Set 6 | khasan
# Processing Record 14 of Set 6 | adrar
# Processing Record 15 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 16 of Set 6 | formosa
# Processing Record 17 of Set 6 | kichmengskiy gorodok
# Processing Record 18 of Set 6 | gimli
# Processing Record 19 of Set 6 | dicabisagan
# Processing Record 20 of Set 6 | binzhou
# Processing Record 21 of Set 6 | axim
# Processing Record 22 of Set 6 | ridgecrest
# Processing Record 23 of Set 6 | hasaki
# Processing Record 24 of Set 6 | bonavista
# Processing Record 25 of Set 6 | yuryuzan
# Processing Record 26 of Set 6 | klaksvik
# Processing Record 27 of Set 6 | safonovo
# Processing Record 28 of Set 6 | pochutla
# Processing Record 29 of Set 6 | ribeira grande
# Processing Record 30 of Set 6 | ust-nera
# Processing Record 31 of Set 6 | mahebourg
# Processing Record 32 of Set 6 | iqaluit
# Processing Record 33 of Set 6 | dukat
# Processing Record 34 of Set 6 | tangshan
# Processing Record 35 of Set 6 | inirida
# Processing Record 36 of Set 6 | mashhad
# Processing Record 37 of Set 6 | ixtapa
# Processing Record 38 of Set 6 | gamboma
# Processing Record 39 of Set 6 | west bay
# Processing Record 40 of Set 6 | karpathos
# Processing Record 41 of Set 6 | tessalit
# Processing Record 42 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 43 of Set 6 | gebre guracha
# Processing Record 44 of Set 6 | lulea
# Processing Record 45 of Set 6 | san fernando
# Processing Record 46 of Set 6 | ortakoy
# Processing Record 47 of Set 6 | salym
# Processing Record 48 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 49 of Set 6 | sotnikovo
# Processing Record 50 of Set 6 | aklavik
# Processing Record 1 of Set 7 | sorong
# Processing Record 2 of Set 7 | provideniya
# Processing Record 3 of Set 7 | harindanga
# Processing Record 4 of Set 7 | sayyan
# Processing Record 5 of Set 7 | bathsheba
# Processing Record 6 of Set 7 | mosquera
# Processing Record 7 of Set 7 | tommot
# Processing Record 8 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 9 of Set 7 | leningradskiy
# Processing Record 10 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 11 of Set 7 | lasem
# Processing Record 12 of Set 7 | umm lajj
# Processing Record 13 of Set 7 | imbituba
# Processing Record 14 of Set 7 | mahajanga
# Processing Record 15 of Set 7 | faya
# Processing Record 16 of Set 7 | strezhevoy
# Processing Record 17 of Set 7 | bambous virieux
# Processing Record 18 of Set 7 | kovdor
# Processing Record 19 of Set 7 | acapulco
# Processing Record 20 of Set 7 | broome
# Processing Record 21 of Set 7 | vostok
# Processing Record 22 of Set 7 | san lawrenz
# Processing Record 23 of Set 7 | baghdad
# Processing Record 24 of Set 7 | beisfjord
# Processing Record 25 of Set 7 | bandar-e anzali
# Processing Record 26 of Set 7 | san patricio
# Processing Record 27 of Set 7 | sao felix do xingu
# Processing Record 28 of Set 7 | calabozo
# Processing Record 29 of Set 7 | vila do maio
# Processing Record 30 of Set 7 | chimore
# Processing Record 31 of Set 7 | dubbo
# Processing Record 32 of Set 7 | olafsvik
# Processing Record 33 of Set 7 | presidencia roque saenz pena
# Processing Record 34 of Set 7 | formosa do rio preto
# Processing Record 35 of Set 7 | zhigansk
# Processing Record 36 of Set 7 | vangaindrano
# Processing Record 37 of Set 7 | sobolevo
# Processing Record 38 of Set 7 | el cobre
# Processing Record 39 of Set 7 | havoysund
# Processing Record 40 of Set 7 | chaumont
# Processing Record 41 of Set 7 | ozernovskiy
# Processing Record 42 of Set 7 | vinzili
# Processing Record 43 of Set 7 | pisco
# Processing Record 44 of Set 7 | tual
# Processing Record 45 of Set 7 | barao de melgaco
# Processing Record 46 of Set 7 | ahuimanu
# Processing Record 47 of Set 7 | marawi
# Processing Record 48 of Set 7 | rafaela
# Processing Record 49 of Set 7 | saint-augustin
# Processing Record 50 of Set 7 | iracoubo
# Processing Record 1 of Set 8 | ilulissat
# Processing Record 2 of Set 8 | alyangula
# Processing Record 3 of Set 8 | abalak
# Processing Record 4 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 5 of Set 8 | calmar
# Processing Record 6 of Set 8 | totness
# Processing Record 7 of Set 8 | saint-joseph
# Processing Record 8 of Set 8 | sur
# Processing Record 9 of Set 8 | mehamn
# Processing Record 10 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 11 of Set 8 | fortuna
# Processing Record 12 of Set 8 | vila velha
# Processing Record 13 of Set 8 | tiznit
# Processing Record 14 of Set 8 | haimen
# Processing Record 15 of Set 8 | phan rang
# City not found. Skipping...
# Processing Record 16 of Set 8 | san quintin
# Processing Record 17 of Set 8 | fujin
# Processing Record 18 of Set 8 | ous
# Processing Record 19 of Set 8 | kupang
# Processing Record 20 of Set 8 | gawler
# Processing Record 21 of Set 8 | bud
# Processing Record 22 of Set 8 | presidente medici
# Processing Record 23 of Set 8 | otane
# Processing Record 24 of Set 8 | ituni
# City not found. Skipping...
# Processing Record 25 of Set 8 | sisimiut
# Processing Record 26 of Set 8 | coihaique
# Processing Record 27 of Set 8 | cortez
# Processing Record 28 of Set 8 | phuntsholing
# Processing Record 29 of Set 8 | mtsensk
# Processing Record 30 of Set 8 | port blair
# Processing Record 31 of Set 8 | urumqi
# Processing Record 32 of Set 8 | catamarca
# Processing Record 33 of Set 8 | hendek
# Processing Record 34 of Set 8 | megion
# Processing Record 35 of Set 8 | yumen
# Processing Record 36 of Set 8 | payson
# Processing Record 37 of Set 8 | tazovskiy
# Processing Record 38 of Set 8 | kokopo
# Processing Record 39 of Set 8 | trairi
# Processing Record 40 of Set 8 | aripuana
# Processing Record 41 of Set 8 | tahta
# Processing Record 42 of Set 8 | ajdabiya
# Processing Record 43 of Set 8 | marsa matruh
# Processing Record 44 of Set 8 | saskylakh
# Processing Record 45 of Set 8 | santa luzia
# Processing Record 46 of Set 8 | dingle
# Processing Record 47 of Set 8 | pangnirtung
# Processing Record 48 of Set 8 | romny
# Processing Record 49 of Set 8 | olenegorsk
# Processing Record 50 of Set 8 | long beach
# Processing Record 1 of Set 9 | kieta
# Processing Record 2 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 3 of Set 9 | balkhash
# Processing Record 4 of Set 9 | comodoro rivadavia
# Processing Record 5 of Set 9 | luderitz
# Processing Record 6 of Set 9 | broken hill
# Processing Record 7 of Set 9 | quatre cocos
# Processing Record 8 of Set 9 | pishin
# Processing Record 9 of Set 9 | kochi
# Processing Record 10 of Set 9 | faanui
# Processing Record 11 of Set 9 | tyrma
# Processing Record 12 of Set 9 | diu
# Processing Record 13 of Set 9 | tadine
# Processing Record 14 of Set 9 | sokoni
# Processing Record 15 of Set 9 | namyslow
# Processing Record 16 of Set 9 | neiafu
# Processing Record 17 of Set 9 | ekhabi
# Processing Record 18 of Set 9 | fort saint james
# Processing Record 19 of Set 9 | winnemucca
# Processing Record 20 of Set 9 | salinas
# Processing Record 21 of Set 9 | batemans bay
# Processing Record 22 of Set 9 | hualmay
# Processing Record 23 of Set 9 | beyla
# Processing Record 24 of Set 9 | shingu
# Processing Record 25 of Set 9 | najran
# Processing Record 26 of Set 9 | dikson
# Processing Record 27 of Set 9 | mayumba
# Processing Record 28 of Set 9 | sarh
# Processing Record 29 of Set 9 | la palma
# Processing Record 30 of Set 9 | kurush
# Processing Record 31 of Set 9 | tuatapere
# Processing Record 32 of Set 9 | wonthaggi
# Processing Record 33 of Set 9 | linhares
# Processing Record 34 of Set 9 | kloulklubed
# Processing Record 35 of Set 9 | tanah merah
# Processing Record 36 of Set 9 | north bend
# Processing Record 37 of Set 9 | otjimbingwe
# Processing Record 38 of Set 9 | khandyga
# Processing Record 39 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 9 | nemuro
# Processing Record 41 of Set 9 | alamosa
# Processing Record 42 of Set 9 | shenkursk
# Processing Record 43 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 44 of Set 9 | necochea
# Processing Record 45 of Set 9 | panzhihua
# Processing Record 46 of Set 9 | codrington
# Processing Record 47 of Set 9 | tura
# Processing Record 48 of Set 9 | orlik
# Processing Record 49 of Set 9 | strelka
# Processing Record 50 of Set 9 | beyneu
# Processing Record 1 of Set 10 | dunedin
# Processing Record 2 of Set 10 | asau
# Processing Record 3 of Set 10 | buraydah
# Processing Record 4 of Set 10 | nguru
# Processing Record 5 of Set 10 | vanimo
# Processing Record 6 of Set 10 | santa fe
# Processing Record 7 of Set 10 | clyde river
# Processing Record 8 of Set 10 | candawaga
# City not found. Skipping...
# Processing Record 9 of Set 10 | iranshahr
# Processing Record 10 of Set 10 | amazar
# Processing Record 11 of Set 10 | port keats
# Processing Record 12 of Set 10 | zwettl
# Processing Record 13 of Set 10 | jodhpur
# Processing Record 14 of Set 10 | sterling
# Processing Record 15 of Set 10 | vila franca do campo
# Processing Record 16 of Set 10 | rio grande
# Processing Record 17 of Set 10 | balkanabat
# Processing Record 18 of Set 10 | issa
# Processing Record 19 of Set 10 | de-kastri
# Processing Record 20 of Set 10 | muros
# Processing Record 21 of Set 10 | umm kaddadah
# Processing Record 22 of Set 10 | mapiripan
# Processing Record 23 of Set 10 | devils lake
# Processing Record 24 of Set 10 | araxa
# Processing Record 25 of Set 10 | nanzhang
# Processing Record 26 of Set 10 | palu
# Processing Record 27 of Set 10 | cockburn town
# Processing Record 28 of Set 10 | seydi
# Processing Record 29 of Set 10 | nambucca heads
# Processing Record 30 of Set 10 | ojinaga
# Processing Record 31 of Set 10 | queanbeyan
# Processing Record 32 of Set 10 | great yarmouth
# Processing Record 33 of Set 10 | isangel
# Processing Record 34 of Set 10 | ostuni
# Processing Record 35 of Set 10 | valle de allende
# Processing Record 36 of Set 10 | egvekinot
# Processing Record 37 of Set 10 | puerto lleras
# Processing Record 38 of Set 10 | naxos
# Processing Record 39 of Set 10 | skjern
# Processing Record 40 of Set 10 | kapoeta
# Processing Record 41 of Set 10 | hervey bay
# Processing Record 42 of Set 10 | correntina
# Processing Record 43 of Set 10 | waddan
# Processing Record 44 of Set 10 | zlitan
# Processing Record 45 of Set 10 | yatou
# Processing Record 46 of Set 10 | nagato
# Processing Record 47 of Set 10 | villemomble
# Processing Record 48 of Set 10 | borovoy
# Processing Record 49 of Set 10 | banda aceh
# Processing Record 50 of Set 10 | san ramon
# Processing Record 1 of Set 11 | havelock
# Processing Record 2 of Set 11 | anadyr
# Processing Record 3 of Set 11 | skagastrond
# City not found. Skipping...
# Processing Record 4 of Set 11 | dire
# Processing Record 5 of Set 11 | padang
# Processing Record 6 of Set 11 | touros
# Processing Record 7 of Set 11 | jutai
# Processing Record 8 of Set 11 | tungor
# Processing Record 9 of Set 11 | arraial do cabo
# Processing Record 10 of Set 11 | aborlan
# Processing Record 11 of Set 11 | chagoda
# Processing Record 12 of Set 11 | ambatondrazaka
# Processing Record 13 of Set 11 | xam nua
# Processing Record 14 of Set 11 | tarare
# Processing Record 15 of Set 11 | deputatskiy
# Processing Record 16 of Set 11 | hamilton
# Processing Record 17 of Set 11 | gat
# Processing Record 18 of Set 11 | beni
# Processing Record 19 of Set 11 | shakawe
# Processing Record 20 of Set 11 | ruteng
# Processing Record 21 of Set 11 | beira
# Processing Record 22 of Set 11 | kaitangata
# Processing Record 23 of Set 11 | ostrovnoy
# Processing Record 24 of Set 11 | maracaibo
# Processing Record 25 of Set 11 | canto do buriti
# Processing Record 26 of Set 11 | tigil
# Processing Record 27 of Set 11 | dankov
# Processing Record 28 of Set 11 | grenville
# Processing Record 29 of Set 11 | kakucs
# Processing Record 30 of Set 11 | tahe
# Processing Record 31 of Set 11 | lugovskoy
# Processing Record 32 of Set 11 | juifang
# City not found. Skipping...
# Processing Record 33 of Set 11 | teguise
# Processing Record 34 of Set 11 | tipitapa
# Processing Record 35 of Set 11 | sayat
# Processing Record 36 of Set 11 | salalah
# Processing Record 37 of Set 11 | ormara
# Processing Record 38 of Set 11 | kedrovyy
# Processing Record 39 of Set 11 | sola
# Processing Record 40 of Set 11 | yirol
# City not found. Skipping...
# Processing Record 41 of Set 11 | port macquarie
# Processing Record 42 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 43 of Set 11 | debre birhan
# Processing Record 44 of Set 11 | farafangana
# Processing Record 45 of Set 11 | requena
# Processing Record 46 of Set 11 | miles city
# Processing Record 47 of Set 11 | gardan diwal
# City not found. Skipping...
# Processing Record 48 of Set 11 | krasnoselkup
# Processing Record 49 of Set 11 | santa cruz de rosales
# City not found. Skipping...
# Processing Record 50 of Set 11 | flagstaff
# Processing Record 1 of Set 12 | wyndham
# Processing Record 2 of Set 12 | nuuk
# Processing Record 3 of Set 12 | sangar
# Processing Record 4 of Set 12 | rongcheng
# Processing Record 5 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 6 of Set 12 | noumea
# Processing Record 7 of Set 12 | marrakesh
# Processing Record 8 of Set 12 | boffa
# Processing Record 9 of Set 12 | cayenne
# Processing Record 10 of Set 12 | santander
# Processing Record 11 of Set 12 | kaniama
# Processing Record 12 of Set 12 | yancheng
# Processing Record 13 of Set 12 | sakata
# Processing Record 14 of Set 12 | zhangye
# Processing Record 15 of Set 12 | haradok
# Processing Record 16 of Set 12 | kungurtug
# Processing Record 17 of Set 12 | killybegs
# Processing Record 18 of Set 12 | okoneshnikovo
# Processing Record 19 of Set 12 | linqing
# Processing Record 20 of Set 12 | xichang
# Processing Record 21 of Set 12 | tullamore
# Processing Record 22 of Set 12 | inyonga
# Processing Record 23 of Set 12 | ankang
# Processing Record 24 of Set 12 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 25 of Set 12 | mogwase
# Processing Record 26 of Set 12 | carman
# Processing Record 27 of Set 12 | appingedam
# Processing Record 28 of Set 12 | eufaula
# Processing Record 29 of Set 12 | gamba
# Processing Record 30 of Set 12 | saint george
# Processing Record 31 of Set 12 | grindavik
# Processing Record 32 of Set 12 | hohhot
# Processing Record 33 of Set 12 | sorland
# Processing Record 34 of Set 12 | belaya gora
# Processing Record 35 of Set 12 | vardo
# Processing Record 36 of Set 12 | micheweni
# Processing Record 37 of Set 12 | yabelo
# Processing Record 38 of Set 12 | goroka
# Processing Record 39 of Set 12 | ishigaki
# Processing Record 40 of Set 12 | hauterive
# Processing Record 41 of Set 12 | oktyabrskiy
# Processing Record 42 of Set 12 | tselinnoye
# Processing Record 43 of Set 12 | rosario do sul
# Processing Record 44 of Set 12 | schleswig
# Processing Record 45 of Set 12 | kailua
# Processing Record 46 of Set 12 | rio gallegos
# Processing Record 47 of Set 12 | itaituba
# Processing Record 48 of Set 12 | sigli
# Processing Record 49 of Set 12 | borama
# City not found. Skipping...
# Processing Record 50 of Set 12 | paignton
# Processing Record 1 of Set 13 | qaqortoq
# Processing Record 2 of Set 13 | esso
# Processing Record 3 of Set 13 | campbellsville
# Processing Record 4 of Set 13 | ialibu
# Processing Record 5 of Set 13 | sinop
# Processing Record 6 of Set 13 | richards bay
# Processing Record 7 of Set 13 | oussouye
# Processing Record 8 of Set 13 | poum
# Processing Record 9 of Set 13 | yanchukan
# City not found. Skipping...
# Processing Record 10 of Set 13 | lenina
# Processing Record 11 of Set 13 | kontagora
# Processing Record 12 of Set 13 | thai binh
# Processing Record 13 of Set 13 | dwarka
# Processing Record 14 of Set 13 | arrecife
# Processing Record 15 of Set 13 | juniyah
# City not found. Skipping...
# Processing Record 16 of Set 13 | mocuba
# Processing Record 17 of Set 13 | aykhal
# Processing Record 18 of Set 13 | sturgeon falls
# Processing Record 19 of Set 13 | samarai
# Processing Record 20 of Set 13 | longlac
# City not found. Skipping...
# Processing Record 21 of Set 13 | narsaq
# Processing Record 22 of Set 13 | limay
# Processing Record 23 of Set 13 | burica
# City not found. Skipping...
# Processing Record 24 of Set 13 | taoudenni
# Processing Record 25 of Set 13 | bratsk
# Processing Record 26 of Set 13 | zyryanovsk
# Processing Record 27 of Set 13 | minsk
# Processing Record 28 of Set 13 | port-gentil
# Processing Record 29 of Set 13 | puerto colombia
# Processing Record 30 of Set 13 | maldonado
# Processing Record 31 of Set 13 | tidore
# City not found. Skipping...
# Processing Record 32 of Set 13 | porto santo
# Processing Record 33 of Set 13 | codajas
# Processing Record 34 of Set 13 | saint anthony
# Processing Record 35 of Set 13 | storforshei
# Processing Record 36 of Set 13 | polunochnoye
# Processing Record 37 of Set 13 | yerofey pavlovich
# Processing Record 38 of Set 13 | anqing
# Processing Record 39 of Set 13 | pasni
# Processing Record 40 of Set 13 | ovre ardal
# Processing Record 41 of Set 13 | kepno
# Processing Record 42 of Set 13 | mizdah
# Processing Record 43 of Set 13 | canmore
# Processing Record 44 of Set 13 | yeppoon
# Processing Record 45 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 46 of Set 13 | katesh
# Processing Record 47 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 48 of Set 13 | santa cruz do sul
# Processing Record 49 of Set 13 | yuxia
# Processing Record 50 of Set 13 | kenai
# Processing Record 1 of Set 14 | mweka
# Processing Record 2 of Set 14 | tias
# Processing Record 3 of Set 14 | isiro
# Processing Record 4 of Set 14 | dunhua
# Processing Record 5 of Set 14 | bridlington
# Processing Record 6 of Set 14 | batan
# Processing Record 7 of Set 14 | saint-pierre
# Processing Record 8 of Set 14 | cap malheureux
# Processing Record 9 of Set 14 | wenling
# Processing Record 10 of Set 14 | mitchell
# Processing Record 11 of Set 14 | denia
# Processing Record 12 of Set 14 | karratha
# Processing Record 13 of Set 14 | peniche
# Processing Record 14 of Set 14 | goedereede
# Processing Record 15 of Set 14 | gram
# Processing Record 16 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 17 of Set 14 | soyo
# Processing Record 18 of Set 14 | ushtobe
# Processing Record 19 of Set 14 | meulaboh
# Processing Record 20 of Set 14 | san policarpo
# Processing Record 21 of Set 14 | anderson
# Processing Record 22 of Set 14 | charters towers
# Processing Record 23 of Set 14 | orizatlan
# Processing Record 24 of Set 14 | haaksbergen
# Processing Record 25 of Set 14 | palmas bellas
# Processing Record 26 of Set 14 | newport
# Processing Record 27 of Set 14 | gobardanga
# Processing Record 28 of Set 14 | guapi
# Processing Record 29 of Set 14 | calvia
# Processing Record 30 of Set 14 | owando
# Processing Record 31 of Set 14 | conde
# Processing Record 32 of Set 14 | wuxue
# Processing Record 33 of Set 14 | danjiangkou
# Processing Record 34 of Set 14 | rasulnagar
# Processing Record 35 of Set 14 | manavalakurichi
# Processing Record 36 of Set 14 | terrace
# Processing Record 37 of Set 14 | riyadh
# Processing Record 38 of Set 14 | marienburg
# Processing Record 39 of Set 14 | college
# Processing Record 40 of Set 14 | biak
# Processing Record 41 of Set 14 | samdari
# Processing Record 42 of Set 14 | luwuk
# Processing Record 43 of Set 14 | porbandar
# Processing Record 44 of Set 14 | porto nacional
# Processing Record 45 of Set 14 | bilma
# Processing Record 46 of Set 14 | ocos
# Processing Record 47 of Set 14 | grand baie
# Processing Record 48 of Set 14 | kashmor
# Processing Record 49 of Set 14 | biloela
# Processing Record 50 of Set 14 | estelle
# Processing Record 1 of Set 15 | ambulu
# Processing Record 2 of Set 15 | marabba
# Processing Record 3 of Set 15 | matara
# Processing Record 4 of Set 15 | klyuchi
# Processing Record 5 of Set 15 | grants
# Processing Record 6 of Set 15 | dom pedrito
# Processing Record 7 of Set 15 | launceston
# Processing Record 8 of Set 15 | burlington
# Processing Record 9 of Set 15 | vanavara
# Processing Record 10 of Set 15 | banikoara
# Processing Record 11 of Set 15 | buzmeyin
# Processing Record 12 of Set 15 | tautira
# Processing Record 13 of Set 15 | isa khel
# Processing Record 14 of Set 15 | krasnovishersk
# Processing Record 15 of Set 15 | longkou
# Processing Record 16 of Set 15 | truth or consequences
# Processing Record 17 of Set 15 | caravelas
# Processing Record 18 of Set 15 | brae
# Processing Record 19 of Set 15 | tarangnan
# Processing Record 20 of Set 15 | siniscola
# Processing Record 21 of Set 15 | paso de carrasco
# Processing Record 22 of Set 15 | nome
# Processing Record 23 of Set 15 | eyl
# Processing Record 24 of Set 15 | kholodnyy
# Processing Record 25 of Set 15 | zeya
# Processing Record 26 of Set 15 | itatskiy
# Processing Record 27 of Set 15 | tuggurt
# City not found. Skipping...
# Processing Record 28 of Set 15 | yar-sale
# Processing Record 29 of Set 15 | muroto
# Processing Record 30 of Set 15 | polis
# Processing Record 31 of Set 15 | pitimbu
# Processing Record 32 of Set 15 | matay
# Processing Record 33 of Set 15 | aswan
# Processing Record 34 of Set 15 | mikhaylovka
# Processing Record 35 of Set 15 | van buren
# Processing Record 36 of Set 15 | port lincoln
# Processing Record 37 of Set 15 | doha
# Processing Record 38 of Set 15 | atasu
# Processing Record 39 of Set 15 | nioro
# Processing Record 40 of Set 15 | port-cartier
# Processing Record 41 of Set 15 | mount pleasant
# Processing Record 42 of Set 15 | kalispell
# Processing Record 43 of Set 15 | bargal
# City not found. Skipping...
# Processing Record 44 of Set 15 | huarmey
# Processing Record 45 of Set 15 | watari
# Processing Record 46 of Set 15 | walvis bay
# Processing Record 47 of Set 15 | tarnogskiy gorodok
# Processing Record 48 of Set 15 | bulgan
# Processing Record 49 of Set 15 | springfield
# Processing Record 50 of Set 15 | ketchikan
# Processing Record 1 of Set 16 | sangre grande
# Processing Record 2 of Set 16 | la primavera
# Processing Record 3 of Set 16 | beringovskiy
# Processing Record 4 of Set 16 | concarneau
# Processing Record 5 of Set 16 | powell river
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 699

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Bengkulu  -3.8004  102.2655     75.16        95          99        5.01
# 1   Nowy Sacz  49.6218   20.6971     59.11        97         100        3.33
# 2    Portland  45.5234 -122.6762     74.79        70           0        7.00
# 3    Tasiilaq  65.6145  -37.6368     41.16        99         100        4.99
# 4  Butaritari   3.0707  172.7902     81.52        76         100       15.46
# 5    Cherskiy  68.7500  161.3000     29.61        98         100        2.57
# 6     Rikitea -23.1203 -134.9692     73.71        72          81       10.11
# 7   Busselton -33.6500  115.3333     54.82        86          45       14.67
# 8      Albany  42.6001  -73.9662     60.93        65         100        1.01
# 9      Hobart -42.8794  147.3294     44.46        81           8        6.91
#
#   Country       Description
# 0      ID     moderate rain
# 1      PL     moderate rain
# 2      US         clear sky
# 3      GL        light rain
# 4      KI        light rain
# 5      RU        light snow
# 6      PF     broken clouds
# 7      AU  scattered clouds
# 8      US   overcast clouds
# 9      AU         clear sky

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
city_data_df = city_data_df[["City", "Country", "Lat", "Lng","Max Temp", "Humidity", "Cloudiness","Wind Speed", "Description"]]


# Recreate the DataFrame by using the new column order
city_data_df

# Display sample data
city_data_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Bengkulu      ID  -3.8004  102.2655     75.16        95          99
# 1   Nowy Sacz      PL  49.6218   20.6971     59.11        97         100
# 2    Portland      US  45.5234 -122.6762     74.79        70           0
# 3    Tasiilaq      GL  65.6145  -37.6368     41.16        99         100
# 4  Butaritari      KI   3.0707  172.7902     81.52        76         100
# 5    Cherskiy      RU  68.7500  161.3000     29.61        98         100
# 6     Rikitea      PF -23.1203 -134.9692     73.71        72          81
# 7   Busselton      AU -33.6500  115.3333     54.82        86          45
# 8      Albany      US  42.6001  -73.9662     60.93        65         100
# 9      Hobart      AU -42.8794  147.3294     44.46        81           8
#
#    Wind Speed       Description
# 0        5.01     moderate rain
# 1        3.33     moderate rain
# 2        7.00         clear sky
# 3        4.99        light rain
# 4       15.46        light rain
# 5        2.57        light snow
# 6       10.11     broken clouds
# 7       14.67  scattered clouds
# 8        1.01   overcast clouds
# 9        6.91         clear sky

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City            object
# Country         object
# Lat            float64
# Lng            float64
# Max Temp       float64
# Humidity         int64
# Cloudiness       int64
# Wind Speed     float64
# Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "/Users/alicetamiazzo/Desktop/World_Weather_Analysis_2/Weather_Database/weatherpy_database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
